# %% [markdown]
# # Email Classification Model Training
#
# This notebook trains custom machine learning models for email classification.
#
# **Models trained:**
# 1. Category Classifier (8 classes): Work, Personal, Finance, Travel, Shopping, Promotions, Spam, Other
# 2. Priority Classifier (3 classes): High, Medium, Low
#
# **Approach:**
# - Use TF-IDF for text feature extraction
# - Train separate classifiers for category and priority
# - Evaluate models using accuracy, precision, recall, and F1-score
# - Save trained models for production use

# %% [markdown]
# ## 1. Import Libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np
import re
import json
from datetime import datetime

# Text processing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Metrics
from sklearn.metrics import (
    accuracy_score, 
    classification_report, 
    confusion_matrix,
    f1_score
)

# Model persistence
import joblib
import pickle
from pathlib import Path

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Warnings
import warnings
warnings.filterwarnings('ignore')

print("✅ All libraries imported successfully!")

# %% [markdown]
# ## 2. Create Synthetic Training Dataset
#
# Since we're starting fresh, we'll create a synthetic dataset with realistic email patterns.
# In production, you can replace this with real emails from your Supabase database.
